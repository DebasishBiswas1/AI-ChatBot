# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
document = [
  "need to learn machine learning",
  "will go to the machiine learning class today",
  "Ai is used very much these days"
]

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="gemini-embedding-2-preview")
vector = embeddings.embed_documents(document)
len(vector[0])
# Out:
# 3072

# %% [markdown]
# #### Storing the vector embeddings into vector db

# %%
from langchain_chroma import Chroma

# %%
vector_store = Chroma.from_texts(
    texts=document,
    embedding=embeddings,
    persist_directory="./Vector_db"
)

query = "Machine Learning"
results = vector_store.similarity_search(query=query)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 vector_store = Chroma.from_texts(
#       2     texts=document,
#       3     embedding=embeddings,
#       4     persist_directory="./Vector_db"
#
# File d:\project\GENAI-Series\venv\Lib\site-packages\langchain_chroma\vectorstores.py:1365, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, host, port, headers, chroma_cloud_api_key, tenant, database, client_settings, client, collection_metadata, collection_configuration, ssl, **kwargs)
#    1357     from chromadb.utils.batch_utils import create_batches
#    1359     for batch in create_batches(
#    1360         api=chroma_collection._client,
#    1361         ids=ids,
#    1362         metadatas=metadatas,  # type: ignore[arg-type]
#    1363         documents=texts,
#    1364     ):
# ...
