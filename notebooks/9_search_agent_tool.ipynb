# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent
llm = ChatGroq(model="llama-3.3-70b-versatile")
search = GoogleSerperAPIWrapper()

# %%
# search.run("What is the temperature in NewTown, Kolkata in celsius?")

# %%
agent = create_agent(model = llm,
                     tools = [search.run],
                     system_prompt="You are a agent and can search for any question from google.")

# %%
question = "What is the temperature in NewTown, Kolkata in celsius?"
response = agent.invoke({"messages": [{"role": "user", "content": question}]})
response["messages"][-1].content
# Out:
# 'The current temperature in NewTown, Kolkata is 24°C.'
