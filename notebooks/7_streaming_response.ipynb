# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(
    model="groq/compound",
    streaming=True)

# %%
response = llm.stream("Explain neural networks in details")
for chunk in response:
    print(chunk.content, end="")
# Out:
# Below is a complete, detailed explanation of neural networks, incorporating all of the reasoning, concepts, and the illustrative Python example that was previously provided.
#
# ---
#
# ## 1. What Is a Neural Network?
#
# A **neural network** is a computational model inspired by the structure and function of the human brain. It consists of many simple processing units called **neurons** (or **nodes**) that are arranged in layers and connected by **weights**. By adjusting these weights during training, the network learns to map inputs to desired outputs.
#
# ---
#
# ## 2. Core Components
#
# | Component | Role |
# |-----------|------|
# | **Artificial Neuron (Node)** | Receives one or more inputs, computes a weighted sum, adds a bias, applies an activation function, and passes the result forward. |
# | **Connection (Edge)** | Links two neurons; each connection carries a **weight** that scales the signal. |
# ...
