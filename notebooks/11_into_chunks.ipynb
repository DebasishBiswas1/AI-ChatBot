# %%
from dotenv  import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text = "Truganini (1812 to 8 May 1876) was an Aboriginal Tasmanian woman of the Nuenonne people who was once widely described as the last surviving Aboriginal Tasmanian. She grew up on Bruny Island and saw the death and displacement of much of Tasmania's Aboriginal population during the Black War. She accompanied George Augustus Robinson as a guide on expeditions that resulted in the exile of Tasmania's remaining Aboriginal population; Truganini herself was exiled to the Wybalenna Aboriginal Establishment after the expeditions in 1835. She spent a period in the Port Phillip District (modern-day Victoria) where she was tried and acquitted for involvement in the murder of two whalers. She was later moved to Oyster Cove, where by 1872 she was the only Aboriginal resident left and was mythologised as the last of her race. The narrative that Truganini was the last Aboriginal Tasmanian is rejected by scholars and by the contemporary Aboriginal Tasmanian community"

splitter = RecursiveCharacterTextSplitter(chunk_size = 50, chunk_overlap = 20)

chunks = splitter.split_text(text)

# %%
chunks
# Out:
# ['Truganini (1812 to 8 May 1876) was an Aboriginal',
#  'was an Aboriginal Tasmanian woman of the Nuenonne',
#  'of the Nuenonne people who was once widely',
#  'who was once widely described as the last',
#  'as the last surviving Aboriginal Tasmanian. She',
#  'Tasmanian. She grew up on Bruny Island and saw',
#  'Island and saw the death and displacement of much',
#  "of much of Tasmania's Aboriginal population",
#  'population during the Black War. She accompanied',
#  'She accompanied George Augustus Robinson as a',
#  'Robinson as a guide on expeditions that resulted',
#  "that resulted in the exile of Tasmania's",
#  "exile of Tasmania's remaining Aboriginal",
#  'Aboriginal population; Truganini herself was',
#  'herself was exiled to the Wybalenna Aboriginal',
#  'Aboriginal Establishment after the expeditions in',
#  'the expeditions in 1835. She spent a period in',
#  'spent a period in the Port Phillip District',
#  'Phillip District (modern-day Victoria) where she',
#  'Victoria) where she was tried and acquitted for',
#  'and acquitted for involvement in the murder of',
#  'in the murder of two whalers. She was later moved',
#  'She was later moved to Oyster Cove, where by 1872',
#  'Cove, where by 1872 she was the only Aboriginal',
#  'the only Aboriginal resident left and was',
#  'left and was mythologised as the last of her',
#  'as the last of her race. The narrative that',
#  'The narrative that Truganini was the last',
#  'was the last Aboriginal Tasmanian is rejected by',
#  'is rejected by scholars and by the contemporary',
#  'by the contemporary Aboriginal Tasmanian',
#  'Tasmanian community']

# %% [markdown]
# #### Document text loader

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
splitter = RecursiveCharacterTextSplitter(chunk_size=50, chunk_overlap=10)
loader = TextLoader("../data/speech.txt")

# %%
data = loader.load()
text = data[0].page_content

chunk = splitter.split_text(text)
chunk
# Out:
# ['I have last installment left for my rd and it is',
#  'and it is going to be matured bu end of this',
#  'of this month, for this month installment already',
#  'already deducted, so what will happen']
