# %%
from langchain_ollama import ChatOllama

# %%
model = ChatOllama(model="gemma2:2b")

# %%
response = model.invoke("What is the capital of France?")
print(response)
# Out:
# content='The capital of France is **Paris**. 🇫🇷 \n' additional_kwargs={} response_metadata={'model': 'gemma2:2b', 'created_at': '2026-05-01T15:23:29.2622379Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3180010500, 'load_duration': 2943178400, 'prompt_eval_count': 16, 'prompt_eval_duration': 27765700, 'eval_count': 14, 'eval_duration': 183848500, 'logprobs': None, 'model_name': 'gemma2:2b', 'model_provider': 'ollama'} id='lc_run--019de423-35fb-7ac3-8373-24a315baaa9f-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 16, 'output_tokens': 14, 'total_tokens': 30}
